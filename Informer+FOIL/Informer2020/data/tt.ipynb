# %%
unassigned_indices = [23, 50, 58, 59, 83, 120, 128, 130, 139, 176, 178, 185, 190, 197, 199, 250, 273, 285, 304, 308, 320, 337, 348, 351, 441, 446, 448, 460, 467, 475, 476, 496, 528]
num_unassigned = len(unassigned_indices)
print("未被赋值的索引总数为:", num_unassigned)
# Out:
# 未被赋值的索引总数为: 33
